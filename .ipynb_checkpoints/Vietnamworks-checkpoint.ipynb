# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from pandas import DataFrame

def to_int(x):
    return int(x.replace(",",""))

# %%
url="https://jf8q26wwud-dsn.algolia.net/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20JavaScript%20(3.35.1)%3B%20Browser&x-algolia-application-id=JF8Q26WWUD&x-algolia-api-key=2bc790c0d4f44db9ab6267a597d17f1a"

payload={"requests":[{"indexName":"vnw_job_v2","params":"query=&query=&facetFilters=%5B%5D&numericFilters=%5B%5D&page=0&hitsPerPage=50&restrictSearchableAttributes=%5B%22jobTitle%22%2C%22skills%22%2C%22company%22%5D&attributesToRetrieve=%5B%22*%22%2C%22-jobRequirement%22%2C%22-jobDescription%22%5D"}]}

# %%
import json
r = requests.post(url, data=json.dumps(payload))

# %%
total_job = r.json()["results"][0]["nbHits"]

# %%
industry_url="https://www.vietnamworks.com/tim-viec-lam"

page = requests.get(industry_url)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
industries = soup.find("div", class_="highlight").find_all("dd")

full_ind = []
full_no_of_job = []
for industry in industries:
  tmp = industry.get_text().split()
  no_of_jobs=str(tmp[-1])[1:-1]
  tmp = tmp[0:-1]
  ind = " ".join(tmp)
  full_ind.append(ind)
  full_no_of_job.append(int(no_of_jobs))

# %%
Vietnamwork = {
        'Industry': full_ind,
        'Total Jobs': total_job,
        'No. of Jobs': full_no_of_job
        }

df = DataFrame(Vietnamwork, columns= ['Total Jobs', 'Industry', 'No. of Jobs'])

# %%
industries = soup.find_all("div", class_="highlight")[2].find_all("dd")


full_ind = []
full_no_of_job = []

for industry in industries:
  tmp = industry.get_text().split()
  no_of_jobs=str(tmp[-1])[1:-1]
  tmp = tmp[0:-1]
  ind = " ".join(tmp)
  full_ind.append(ind)
  full_no_of_job.append(int(no_of_jobs))

demo = {'Senority': full_ind,
        'Jobs by Senority': full_no_of_job
        }

senority_pd_r = DataFrame(demo, columns= ['Senority', 'Jobs by Senority'])

# %%
s = senority_pd_r.set_index('Senority')
senority_pd = s.transpose()

senority_dict = senority_pd.to_dict()
# d = senority_dict.get(0)
# d
# Vietnamwork.update(senority_dict)

senority_final = {}
for key in senority_dict.keys():
    senority_final[key] = senority_dict[key]["Jobs by Senority"]
Vietnamwork.update(senority_final)

df = DataFrame(Vietnamwork, columns=['Time', 'Total Jobs','Thời vụ/Hợp đồng ngắn hạn','Mới tốt nghiệp','Cấp quản lý điều hành', 'Industry','No. of Jobs'])
df.rename(columns={3:'Intern', 0:'Junior', 2: 'Senior', 1: 'Manager/Director'}, inplace = True)

# %%
df = df.rename(columns={"Thời vụ/Hợp đồng ngắn hạn": "Intern", "Mới tốt nghiệp": "Junior", 'Cấp quản lý điều hành': 'Manager/Director'})
df.sort_values(by=['No. of Jobs'], ascending=False)
# Out:
#    Time  Total Jobs  Intern  Junior  Manager/Director  \
# 11  NaN       12463      19     168               657
# 22  NaN       12463      19     168               657
# 23  NaN       12463      19     168               657
# 0   NaN       12463      19     168               657
# 9   NaN       12463      19     168               657
# 10  NaN       12463      19     168               657
# 6   NaN       12463      19     168               657
# 44  NaN       12463      19     168               657
# 7   NaN       12463      19     168               657
# 41  NaN       12463      19     168               657
# 1   NaN       12463      19     168               657
# 16  NaN       12463      19     168               657
# 5   NaN       12463      19     168               657
# 43  NaN       12463      19     168               657
# 2   NaN       12463      19     168               657
# 30  NaN       12463      19     168               657
# 28  NaN       12463      19     168               657
# 14  NaN       12463      19     168               657
# 17  NaN       12463      19     168               657
# 21  NaN       12463      19     168               657
# 35  NaN       12463      19     168               657
# 42  NaN       12463      19     168               657
# 32  NaN       12463      19     168               657
# 45  NaN       12463      19     168               657
# 4   NaN       12463      19     168               657
# 24  NaN       12463      19     168               657
# 13  NaN       12463      19     168               657
# 20  NaN       12463      19     168               657
# 29  NaN       12463      19     168               657
# 3   NaN       12463      19     168               657
# 18  NaN       12463      19     168               657
# 12  NaN       12463      19     168               657
# 26  NaN       12463      19     168               657
# 25  NaN       12463      19     168               657
# 33  NaN       12463      19     168               657
# 46  NaN       12463      19     168               657
# 39  NaN       12463      19     168               657
# 31  NaN       12463      19     168               657
# 40  NaN       12463      19     168               657
# 38  NaN       12463      19     168               657
# 8   NaN       12463      19     168               657
# 15  NaN       12463      19     168               657
# 27  NaN       12463      19     168               657
# 19  NaN       12463      19     168               657
# 36  NaN       12463      19     168               657
# 37  NaN       12463      19     168               657
# 34  NaN       12463      19     168               657
#
#                             Industry  No. of Jobs
# 11                  Tài chính/Đầu tư         1647
# 22                      Điện/Điện tử         1099
# 23                            Cơ khí          951
# 0                           Xây dựng          949
# 9                          Ngân hàng          843
# 10                         Kiểm toán          836
# 6     Quảng cáo/Khuyến mãi/Đối ngoại          720
# 44              Vận chuyển/Giao nhận          705
# 7              Internet/Online Media          635
# 41                  Giáo dục/Đào tạo          560
# 1        Kiến trúc/Thiết kế nội thất          546
# 16                     Bán lẻ/Bán sỉ          491
# 5       Mỹ Thuật/Nghệ Thuật/Thiết Kế          479
# 43                            Tư vấn          456
# 2                       Bất động sản          445
# 30                  Tự động hóa/Ô tô          431
# 28                   Dệt may/Da giày          397
# 14                    Hàng tiêu dùng          382
# 17               Thực phẩm & Đồ uống          347
# 21                Nhà hàng/Khách sạn          328
# 35            Y tế/Chăm sóc sức khỏe          291
# 42            Y tế/Chăm sóc sức khỏe          291
# 32              Sản phẩm công nghiệp          284
# 45                           Kho vận          271
# 4   Truyền hình/Truyền thông/Báo chí          266
# 24                  Hóa học/Hóa sinh          257
# 13                          Bảo hiểm          223
# 20                Hàng không/Du lịch          220
# 29      Dược Phẩm/Công nghệ sinh học          206
# 3                         Viễn Thông          187
# 18                        Thời trang          147
# 12                       Chứng khoán          142
# 26              Điện lạnh/Nhiệt lạnh          141
# 25        Môi trường/Xử lý chất thải          136
# 33                     Công nghệ cao          136
# 46                          Hàng hải          117
# 39                   Trình dược viên          114
# 31            Nông nghiệp/Lâm nghiệp          112
# 40       Phi chính phủ/Phi lợi nhuận           89
# 38                           Dược sĩ           83
# 8                    In ấn/ Xuất bản           77
# 15                     Hàng gia dụng           71
# 27                           Dầu khí           58
# 19                      Hàng cao cấp           34
# 36                            Bác sĩ           27
# 37                        Y sĩ/Hộ lý           24
# 34               Địa chất/Khoáng sản           23
