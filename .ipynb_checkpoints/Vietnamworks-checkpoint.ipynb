# %%
import requests
import pandas as pd
from datetime import date
from bs4 import BeautifulSoup
from pandas import DataFrame

# %%
#Time by Days
today = date.today()

# %%
url="https://jf8q26wwud-dsn.algolia.net/1/indexes/*/queries?x-algolia-agent=Algolia%20for%20JavaScript%20(3.35.1)%3B%20Browser&x-algolia-application-id=JF8Q26WWUD&x-algolia-api-key=2bc790c0d4f44db9ab6267a597d17f1a"

payload={"requests":[{"indexName":"vnw_job_v2","params":"query=&query=&facetFilters=%5B%5D&numericFilters=%5B%5D&page=0&hitsPerPage=50&restrictSearchableAttributes=%5B%22jobTitle%22%2C%22skills%22%2C%22company%22%5D&attributesToRetrieve=%5B%22*%22%2C%22-jobRequirement%22%2C%22-jobDescription%22%5D"}]}

# %%
import json
r = requests.post(url, data=json.dumps(payload))

# %%
total_job = r.json()["results"][0]["nbHits"]

# %%
industry_url="https://www.vietnamworks.com/tim-viec-lam"

page = requests.get(industry_url)

soup = BeautifulSoup(page.text, 'html.parser')

soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="vi">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="height=device-height,width=device-width,initial-scale=1.0,maximum-scale=1.0, user-scalable=no" name="viewport"/>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible">\n   <meta content="" name="author">\n    <meta content="Tìm kiếm thông tin tuyển dụng và việc làm nhanh hơn tại website việc làm lớn nhất Việt Nam. Cập nhật công việc mới mỗi ngày. Tìm hiểu ngay tại VietnamWorks!" name="description"/>\n    <meta content="tuyển dụng việc làm, tìm việc làm nhanh" name="keywords"/>\n    <meta content="index, follow" name="robots"/>\n    <meta content="telephone=no" name="format-detection"/>\n    <meta content="https://images.vietnamworks.com/img/vnw_logo.png?v=1" property="og:image"/>\n    <meta content="https://images.vietnamworks.com/img/vnw_logo.png?v=1" property="og:image:secure_url"/>\n    <meta content="526" property="og:image:width"/>\n    <meta content="275" property="og:image:height"/>\n    <meta content="Tuyển dụng, việc làm, tìm việc làm nhanh mới nhất  | VietnamWorks" property="og:title"/>\n    <meta content="https://www.vietnamworks.com/tim-viec-lam" property="og:url"/>\n    <meta content="www.vietnamworks.com" property="og:title_name"/>\n    <meta content="Tìm kiếm thông tin tuyển dụng và việc làm nhanh hơn tại website việc làm lớn nhất Việt Nam. Cập nhật công việc mới mỗi ngày. Tìm hiểu ngay tại VietnamWorks!" property="og:description"/>\n    <title>\n     Tuyển dụng, việc làm, tìm việc làm nhanh mới nhất  | VietnamWorks\n    </title>\n    <link href="https://www.vietnamworks.com/tim-viec-lam" rel="canonical"/>\n    <link href="https://www.vietnamworks.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n    <link href="https://fonts.googleapis.com/css?family=Roboto:400,300,500,700&amp;subset=latin,vietnamese" rel="stylesheet" type="text/css"/>\n    <link href="/css/jobseekers/bootstrap.css?version=zr1581416872" rel="stylesheet" type="text/css"/>\n    <link href="/css/font-awesome.css?version=zr1581416872" rel="stylesheet" type="text/css"/>\n    <link href="/css/jobseekers/theme.css?version=zr1581416872" rel="stylesheet" type="text/css"/>\n    <!-- google analytics -->\n    <script type="text/javascript">\n     var _gaq = _gaq || [];\n    var pluginUrl = \'//www.google-analytics.com/plugins/ga/inpage_linkid.js\';\n    _gaq.push([\'_require\', \'inpage_linkid\', pluginUrl]);\n    _gaq.push([\'_setAccount\', \'UA-103236-1\']);\n    _gaq.push([\'_setDomainName\', \'vietnamworks.com\']);\n    _gaq.push([\'_trackPageview\']);\n\n    (function() {\n        var ga = document.createElement(\'script\'); ga.type = \'text/javascript\'; ga.async = true;\n        ga.src = (\'https:\' == document.location.protocol ? \'https://\' : \'http://\') + \'stats.g.doubleclick.net/dc.js\';\n        var s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(ga, s);\n    })();\n    function customEvent (uniqueName, action, label, value) {\n        if (_gaq) {\n            _gaq.push([\'_trackEvent\', uniqueName, action, label], value || 1); // \'Videos\', \'Play\', \'First Birthday\'\n        }\n    }\n    </script>\n    <!-- end google analytics -->\n    <script src="/js/jquery/jquery-1.10.2.min.js" type="text/javascript">\n    </script>\n    <script type="text/javascript">\n     jQuery.curCSS = jQuery.css;\n    </script>\n    <!--[if lt IE 9]>\n        <script type="text/javascript" src="/js/html5shiv.3.7.0.js"></script>\n        <script type="text/javascript" src="/js/respond.1.3.0.min.js"></script>\n        <![endif]-->\n    <script>\n     (function(w, d, s, l, i) {\n            w[l] = w[l] || [];\n            w[l].push({\n                \'gtm.start\': new Date().getTime(), event: \'gtm.js\'\n            });\n            var f = d.getElementsByTagName(s)[0],\n                j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n            j.async = true;\n            j.src =\n                \'//www.goog ...

# %%
industries = soup.find("div", class_="highlight").find_all("dd")

import pandas as pd

full_ind = []
full_no_of_job = []
for industry in industries:
  tmp = industry.get_text().split()
  no_of_jobs=str(tmp[-1])[1:-1]
  tmp = tmp[0:-1]
  ind = " ".join(tmp)
  full_ind.append(ind)
  full_no_of_job.append(int(no_of_jobs))

# %%
from pandas import DataFrame

Vietnamwork = {'Time': today,
        'Industry': full_ind,
        'Total Jobs': total_job,
        'No. of Jobs': full_no_of_job
        }

df = DataFrame(Vietnamwork, columns= ['Time', 'Total Jobs', 'Industry', 'No. of Jobs'])
print(df)
# Out:
#           Time  Total Jobs                          Industry  No. of Jobs
# 0   2020-02-18       12198                          Xây dựng          928
# 1   2020-02-18       12198       Kiến trúc/Thiết kế nội thất          534
# 2   2020-02-18       12198                      Bất động sản          429
# 3   2020-02-18       12198                        Viễn Thông          188
# 4   2020-02-18       12198  Truyền hình/Truyền thông/Báo chí          266
# 5   2020-02-18       12198      Mỹ Thuật/Nghệ Thuật/Thiết Kế          470
# 6   2020-02-18       12198    Quảng cáo/Khuyến mãi/Đối ngoại          710
# 7   2020-02-18       12198             Internet/Online Media          624
# 8   2020-02-18       12198                   In ấn/ Xuất bản           76
# 9   2020-02-18       12198                         Ngân hàng          833
# 10  2020-02-18       12198                         Kiểm toán          819
# 11  2020-02-18       12198                  Tài chính/Đầu tư         1620
# 12  2020-02-18       12198                       Chứng khoán          141
# 13  2020-02-18       12198                          Bảo hiểm          221
# 14  2020-02-18       12198                    Hàng tiêu dùng          374
# 15  2020-02-18       12198                     Hàng gia dụng           70
# 16  2020-02-18       12198                     Bán lẻ/Bán sỉ          487
# 17  2020-02-18       12198               Thực phẩm & Đồ uống          336
# 18  2020-02-18       12198                        Thời trang          139
# 19  2020-02-18       12198                      Hàng cao cấp           34
# 20  2020-02-18       12198                Hàng không/Du lịch          218
# 21  2020-02-18       12198                Nhà hàng/Khách sạn          324
# 22  2020-02-18       12198                      Điện/Điện tử         1072
# 23  2020-02-18       12198                            Cơ khí          923
# 24  2020-02-18       12198                  Hóa học/Hóa sinh          251
# 25  2020-02-18       12198        Môi trường/Xử lý chất thải          131
# 26  2020-02-18       12198              Điện lạnh/Nhiệt lạnh          138
# 27  2020-02-18       12198                           Dầu khí           54
# 28  2020-02-18       12198                   Dệt may/Da giày          383
# 29  2020-02-18       12198      Dược Phẩm/Công nghệ sinh học          196
# 30  2020-02-18       12198                  Tự động hóa/Ô tô          418
# 31  2020-02-18       12198            Nông nghiệp/Lâm nghiệp          107
# 32  2020-02-18       12198              Sản phẩm công nghiệp          276
# 33  2020-02-18       12198                     Công nghệ cao          133
# 34  2020-02-18       12198               Địa chất/Khoáng sản           23
# 35  2020-02-18       12198            Y tế/Chăm sóc sức khỏe          284
# 36  2020-02-18       12198                            Bác sĩ           27
# 37  2020-02-18       12198                        Y sĩ/Hộ lý           24
# 38  2020-02-18       12198                           Dược sĩ           82
# 39  2020-02-18       12198                   Trình dược viên          111
# 40  2020-02-18       12198       Phi chính phủ/Phi lợi nhuận           90
# 41  2020-02-18       12198                  Giáo dục/Đào tạo          550
# 42  2020-02-18       12198            Y tế/Chăm sóc sức khỏe          284
# 43  2020-02-18       12198                            Tư vấn          446
# 44  2020-02-18       12198              Vận chuyển/Giao nhận          693
# 45  2020-02-18       12198                           Kho vận          264
# 46  2020-02-18       12198                          Hàng hải          115

# %%
industries = soup.find_all("div", class_="highlight")[2].find_all("dd")


full_ind = []
full_no_of_job = []

for industry in industries:
  tmp = industry.get_text().split()
  no_of_jobs=str(tmp[-1])[1:-1]
  tmp = tmp[0:-1]
  ind = " ".join(tmp)
  full_ind.append(ind)
  full_no_of_job.append(int(no_of_jobs))

demo = {'Senority': full_ind,
        'Jobs by Senority': full_no_of_job
        }

senority_pd_r = DataFrame(demo, columns= ['Senority', 'Jobs by Senority'])



# moi tot nghiep -> junior
# Cap quan ly dieu hanh -> manager / director
senority_pd_r
# Out:
#                      Senority  Jobs by Senority
# 0              Mới tốt nghiệp               165
# 1       Cấp quản lý điều hành               647
# 2   Thời vụ/Hợp đồng ngắn hạn                20
# 3               Overseas Jobs                28
# 4  Người nước ngoài/Việt Kiều                29

# %%
s = senority_pd_r.set_index('Senority')
senority_pd = s.transpose()

senority_dict = senority_pd.to_dict()
# d = senority_dict.get(0)
# d
# Vietnamwork.update(senority_dict)

senority_final = {}
for key in senority_dict.keys():
    senority_final[key] = senority_dict[key]["Jobs by Senority"]
Vietnamwork.update(senority_final)

df = DataFrame(Vietnamwork, columns=['Time', 'Total Jobs','Thời vụ/Hợp đồng ngắn hạn','Mới tốt nghiệp','Cấp quản lý điều hành', 'Industry','No. of Jobs'])
df.rename(columns={3:'Intern', 0:'Junior', 2: 'Senior', 1: 'Manager/Director'}, inplace = True)
df
# Out:
#           Time  Total Jobs  Thời vụ/Hợp đồng ngắn hạn  Mới tốt nghiệp  \
# 0   2020-02-18       12198                         20             165
# 1   2020-02-18       12198                         20             165
# 2   2020-02-18       12198                         20             165
# 3   2020-02-18       12198                         20             165
# 4   2020-02-18       12198                         20             165
# 5   2020-02-18       12198                         20             165
# 6   2020-02-18       12198                         20             165
# 7   2020-02-18       12198                         20             165
# 8   2020-02-18       12198                         20             165
# 9   2020-02-18       12198                         20             165
# 10  2020-02-18       12198                         20             165
# 11  2020-02-18       12198                         20             165
# 12  2020-02-18       12198                         20             165
# 13  2020-02-18       12198                         20             165
# 14  2020-02-18       12198                         20             165
# 15  2020-02-18       12198                         20             165
# 16  2020-02-18       12198                         20             165
# 17  2020-02-18       12198                         20             165
# 18  2020-02-18       12198                         20             165
# 19  2020-02-18       12198                         20             165
# 20  2020-02-18       12198                         20             165
# 21  2020-02-18       12198                         20             165
# 22  2020-02-18       12198                         20             165
# 23  2020-02-18       12198                         20             165
# 24  2020-02-18       12198                         20             165
# 25  2020-02-18       12198                         20             165
# 26  2020-02-18       12198                         20             165
# 27  2020-02-18       12198                         20             165
# 28  2020-02-18       12198                         20             165
# 29  2020-02-18       12198                         20             165
# 30  2020-02-18       12198                         20             165
# 31  2020-02-18       12198                         20             165
# 32  2020-02-18       12198                         20             165
# 33  2020-02-18       12198                         20             165
# 34  2020-02-18       12198                         20             165
# 35  2020-02-18       12198                         20             165
# 36  2020-02-18       12198                         20             165
# 37  2020-02-18       12198                         20             165
# 38  2020-02-18       12198                         20             165
# 39  2020-02-18       12198                         20             165
# 40  2020-02-18       12198                         20             165
# 41  2020-02-18       12198                         20             165
# 42  2020-02-18       12198                         20             165
# 43  2020-02-18       12198                         20             165
# 44  2020-02-18       12198                         20             165
# 45  2020-02-18       12198                         20             165
# 46  2020-02-18       12198                         20             165
#
#     Cấp quản lý điều hành                          Industry  No. of Jobs
# 0                     647                          Xây dựng          928
# 1                     647       Kiến trúc/Thiết kế nội thất          534
# 2                     647                      Bất động sản          429
# 3                     647                        Viễn Thông          188
# 4                     647  Truyền hình/Truyền thông/Báo chí          266
# 5                     647      Mỹ Thuật/Nghệ Thuật/Thiết Kế          470
# 6                     647    Quảng cáo/Khuyến mãi/Đối ngoại          710
# 7                     647             Internet/Online Media          624
# 8                     647                   In ấn/ Xuất bản           76
# 9                     647                         Ngân hàng          833
# 10                    647                         Kiểm toán          819
# 11                    647                  Tài chính/Đầu tư         1620
# 12                    647                       Chứng khoán          141
# 13                    647                          Bảo hiểm          221
# 14                    647                    Hàng tiêu dùng          374
# 15                    647                     Hàng gia dụng           70
# 16                    647                     Bán lẻ/Bán sỉ          487
# 17                    647               Thực phẩm & Đồ uống          336
# 18                    647                        Thời trang          139
# 19                    647                      Hàng cao cấp           34
# 20                    647                Hàng không/Du lịch          218
# 21                    647                Nhà hàng/Khách sạn          324
# 22                    647                      Điện/Điện tử         1072
# 23                    647                            Cơ khí          923
# 24                    647                  Hóa học/Hóa sinh          251
# 25                    647        Môi trường/Xử lý chất thải          131
# 26                    647              Điện lạnh/Nhiệt lạnh          138
# 27                    647                           Dầu khí           54
# 28                    647                   Dệt may/Da giày          383
# 29                    647      Dược Phẩm/Công nghệ sinh học          196
# 30                    647                  Tự động hóa/Ô tô          418
# 31                    647            Nông nghiệp/Lâm nghiệp          107
# 32                    647              Sản phẩm công nghiệp          276
# 33                    647                     Công nghệ cao          133
# 34                    647               Địa chất/Khoáng sản           23
# 35                    647            Y tế/Chăm sóc sức khỏe          284
# 36                    647                            Bác sĩ           27
# 37                    647                        Y sĩ/Hộ lý           24
# 38                    647                           Dược sĩ           82
# 39                    647                   Trình dược viên          111
# 40                    647       Phi chính phủ/Phi lợi nhuận           90
# 41                    647                  Giáo dục/Đào tạo          550
# 42                    647            Y tế/Chăm sóc sức khỏe          284
# 43                    647                            Tư vấn          446
# 44                    647              Vận chuyển/Giao nhận          693
# 45                    647                           Kho vận          264
# 46                    647                          Hàng hải          115

# %%
df = df.rename(columns={"Thời vụ/Hợp đồng ngắn hạn": "Intern", "Mới tốt nghiệp": "Junior", 'Cấp quản lý điều hành': 'Manager/Director'})
df.sort_values(by=['No. of Jobs'], ascending=False)
# Out:
#           Time  Total Jobs  Intern  Junior  Manager/Director  \
# 11  2020-02-18       12198      20     165               647
# 22  2020-02-18       12198      20     165               647
# 0   2020-02-18       12198      20     165               647
# 23  2020-02-18       12198      20     165               647
# 9   2020-02-18       12198      20     165               647
# 10  2020-02-18       12198      20     165               647
# 6   2020-02-18       12198      20     165               647
# 44  2020-02-18       12198      20     165               647
# 7   2020-02-18       12198      20     165               647
# 41  2020-02-18       12198      20     165               647
# 1   2020-02-18       12198      20     165               647
# 16  2020-02-18       12198      20     165               647
# 5   2020-02-18       12198      20     165               647
# 43  2020-02-18       12198      20     165               647
# 2   2020-02-18       12198      20     165               647
# 30  2020-02-18       12198      20     165               647
# 28  2020-02-18       12198      20     165               647
# 14  2020-02-18       12198      20     165               647
# 17  2020-02-18       12198      20     165               647
# 21  2020-02-18       12198      20     165               647
# 42  2020-02-18       12198      20     165               647
# 35  2020-02-18       12198      20     165               647
# 32  2020-02-18       12198      20     165               647
# 4   2020-02-18       12198      20     165               647
# 45  2020-02-18       12198      20     165               647
# 24  2020-02-18       12198      20     165               647
# 13  2020-02-18       12198      20     165               647
# 20  2020-02-18       12198      20     165               647
# 29  2020-02-18       12198      20     165               647
# 3   2020-02-18       12198      20     165               647
# 12  2020-02-18       12198      20     165               647
# 18  2020-02-18       12198      20     165               647
# 26  2020-02-18       12198      20     165               647
# 33  2020-02-18       12198      20     165               647
# 25  2020-02-18       12198      20     165               647
# 46  2020-02-18       12198      20     165               647
# 39  2020-02-18       12198      20     165               647
# 31  2020-02-18       12198      20     165               647
# 40  2020-02-18       12198      20     165               647
# 38  2020-02-18       12198      20     165               647
# 8   2020-02-18       12198      20     165               647
# 15  2020-02-18       12198      20     165               647
# 27  2020-02-18       12198      20     165               647
# 19  2020-02-18       12198      20     165               647
# 36  2020-02-18       12198      20     165               647
# 37  2020-02-18       12198      20     165               647
# 34  2020-02-18       12198      20     165               647
#
#                             Industry  No. of Jobs
# 11                  Tài chính/Đầu tư         1620
# 22                      Điện/Điện tử         1072
# 0                           Xây dựng          928
# 23                            Cơ khí          923
# 9                          Ngân hàng          833
# 10                         Kiểm toán          819
# 6     Quảng cáo/Khuyến mãi/Đối ngoại          710
# 44              Vận chuyển/Giao nhận          693
# 7              Internet/Online Media          624
# 41                  Giáo dục/Đào tạo          550
# 1        Kiến trúc/Thiết kế nội thất          534
# 16                     Bán lẻ/Bán sỉ          487
# 5       Mỹ Thuật/Nghệ Thuật/Thiết Kế          470
# 43                            Tư vấn          446
# 2                       Bất động sản          429
# 30                  Tự động hóa/Ô tô          418
# 28                   Dệt may/Da giày          383
# 14                    Hàng tiêu dùng          374
# 17               Thực phẩm & Đồ uống          336
# 21                Nhà hàng/Khách sạn          324
# 42            Y tế/Chăm sóc sức khỏe          284
# 35            Y tế/Chăm sóc sức khỏe          284
# 32              Sản phẩm công nghiệp          276
# 4   Truyền hình/Truyền thông/Báo chí          266
# 45                           Kho vận          264
# 24                  Hóa học/Hóa sinh          251
# 13                          Bảo hiểm          221
# 20                Hàng không/Du lịch          218
# 29      Dược Phẩm/Công nghệ sinh học          196
# 3                         Viễn Thông          188
# 12                       Chứng khoán          141
# 18                        Thời trang          139
# 26              Điện lạnh/Nhiệt lạnh          138
# 33                     Công nghệ cao          133
# 25        Môi trường/Xử lý chất thải          131
# 46                          Hàng hải          115
# 39                   Trình dược viên          111
# 31            Nông nghiệp/Lâm nghiệp          107
# 40       Phi chính phủ/Phi lợi nhuận           90
# 38                           Dược sĩ           82
# 8                    In ấn/ Xuất bản           76
# 15                     Hàng gia dụng           70
# 27                           Dầu khí           54
# 19                      Hàng cao cấp           34
# 36                            Bác sĩ           27
# 37                        Y sĩ/Hộ lý           24
# 34               Địa chất/Khoáng sản           23

# %%
df.to_csv("Vietnamworks.csv")

# %%
# !cat sida.csv
# Out:
# ,Mới tốt nghiệp,Cấp quản lý điều hành,Thời vụ/Hợp đồng ngắn hạn,Overseas Jobs,Người nước ngoài/Việt Kiều
# Jobs by Senority,165,647,20,28,29
