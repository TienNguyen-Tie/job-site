# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
from pandas import DataFrame

def to_int(x):
    if type(x) is int:
        return x
    return int(x.replace(",","").replace(".",""))

# %%
#Total Jobs of CareerBuilder
url = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-vi.html"
page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs = soup.find("div", class_="ais-stats").find("span").get_text()
total_jobs = to_int(total_jobs)

# %%
#Jobs by Industry
full_ind = []
full_no_of_jobs = []

industries = soup.find_all('div', class_="ais-refinement-list")[1].find_all("li")

for industry in industries:
    ind = industry.find_all("span")[0].get_text()
    no_of_jobs = industry.find_all("span")[1].get_text()
    full_ind.append(ind)
    full_no_of_jobs.append(to_int(no_of_jobs))

# %%
#Jobs by Senority
#Jobs Sinh Viên
url_sv = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe1-vi.html"

page = requests.get(url_sv)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_sv = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs Tốt nghiệp
url_tn = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe2-vi.html"

page = requests.get(url_tn)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_tn = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs executive
url_nv = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe3-vi.html"

page = requests.get(url_nv)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_nv = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs Senior
url_cv = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe4-vi.html"

page = requests.get(url_cv)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_cv = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs Manager
url_tp = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe5-vi.html"

page = requests.get(url_tp)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_tp = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs Director
url_gd = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe11-vi.html"

page = requests.get(url_gd)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_gd = soup.find("div", class_="ais-stats").find("span").get_text()


#Jobs BoD
url_bdh = "https://careerbuilder.vn/viec-lam/tat-ca-viec-lam-fe12-vi.html"

page = requests.get(url_bdh)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

total_jobs_bdh = soup.find("div", class_="ais-stats").find("span").get_text()

# %%
#Candidate Number
url_candidate = "https://careerbuilder.vn/vi/resume-search.html"

page = requests.get(url_candidate)
soup = BeautifulSoup(page.text, 'html.parser')
soup.prettify()

full_can_ind_dict = {}
result_dict = {}

can_inds = soup.find('div', class_='HeaderLine CateEmp').find_all('li')

for inds in can_inds:
    can_ind = inds.find('a').get_text()
    no_of_can_ind = inds.find('span').get_text()
    no_of_can_ind = no_of_can_ind[1:-1]
    full_can_ind_dict[f'{can_ind}']=to_int(no_of_can_ind)

df1 = pd.DataFrame(full_can_ind_dict.items(), columns = ['Industry','Number of Candidates'])

# %%
#Create DataFrame
CareerBuilder = {
        'Industry': full_ind,
        'No. of Jobs': full_no_of_jobs,
        'Total Jobs': to_int(total_jobs),
        'Intern': to_int(total_jobs_sv),
        'Graduate': to_int(total_jobs_tn),
        'Executive': to_int(total_jobs_nv),
        'Senior': to_int(total_jobs_cv),
        'Manager': to_int(total_jobs_tp),
        'Director': to_int(total_jobs_gd),
        'Board of Director': to_int(total_jobs_bdh)}

df = DataFrame(CareerBuilder, columns= ['Total Jobs', 'Intern', 'Graduate', 'Executive', 'Senior', 'Manager', 'Director', 'Board of Director', 'Industry', 'No. of Jobs'])

# %%
sum_column_1 = df["Graduate"] + df["Executive"]
sum_column_2 = df["Manager"] + df["Director"] + df["Board of Director"]
df["Junior"] = sum_column_1
df['Manager/Director'] = sum_column_2

# %%
#Merge DataFrame
result = pd.merge(df,
                 df1[['Industry', 'Number of Candidates']],
                 on='Industry')
result = result.drop(['Graduate','Executive','Manager','Director','Board of Director'],axis=1)
result
# Out:
#     Total Jobs  Intern  Senior                              Industry  \
# 0        15231     169    1609                 Bán hàng / Kinh doanh
# 1        15231     169    1609                  Tiếp thị / Marketing
# 2        15231     169    1609                   Kế toán / Kiểm toán
# 3        15231     169    1609                             Ngân hàng
# 4        15231     169    1609                    Tài chính / Đầu tư
# 5        15231     169    1609                    Dịch vụ khách hàng
# 6        15231     169    1609                   Hành chính / Thư ký
# 7        15231     169    1609                       Bán lẻ / Bán sỉ
# 8        15231     169    1609                       CNTT - Phần mềm
# 9        15231     169    1609                               Nhân sự
# 10       15231     169    1609            Điện / Điện tử / Điện lạnh
# 11       15231     169    1609          Sản xuất / Vận hành sản xuất
# 12       15231     169    1609           Cơ khí / Ô tô / Tự động hóa
# 13       15231     169    1609                                Tư vấn
# 14       15231     169    1609                              Xây dựng
# 15       15231     169    1609  Quảng cáo / Đối ngoại / Truyền Thông
# 16       15231     169    1609                     Quản lý điều hành
# 17       15231     169    1609               CNTT - Phần cứng / Mạng
# 18       15231     169    1609     Vận chuyển / Giao nhận /  Kho vận
# 19       15231     169    1609                          Bất động sản
#
#     No. of Jobs  Junior  Manager/Director  Number of Candidates
# 0          3874   11593              1860                109624
# 1          1954   11593              1860                 56656
# 2          1940   11593              1860                115941
# 3          1915   11593              1860                 59962
# 4          1758   11593              1860                 22015
# 5          1699   11593              1860                 60794
# 6          1485   11593              1860                108090
# 7          1435   11593              1860                 22778
# 8          1262   11593              1860                 44359
# 9          1126   11593              1860                 74737
# 10         1107   11593              1860                 27712
# 11         1067   11593              1860                 35313
# 12         1032   11593              1860                 48147
# 13          846   11593              1860                 20835
# 14          845   11593              1860                 39840
# 15          840   11593              1860                 11194
# 16          784   11593              1860                 34004
# 17          769   11593              1860                 12172
# 18          729   11593              1860                 21799
# 19          696   11593              1860                 17159
